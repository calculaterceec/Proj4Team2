# %%
import pandas as pd

# %%
# cdc wonder Daily Air Temp by State
# Jan 1, 2011 - Dec 31, 2011
temp_df = pd.read_csv('data/climate_data/2011_AirTemp_byState.txt', delimiter="\t", header=0)
particulateMatter_df = pd.read_csv('data/climate_data/2011_fineParticulateMatter_µgm3.txt', delimiter="\t", header=0)

# %%
particulateMatter_df
# Out:
#                                                    Notes    State  State Code  \
# 0                                                    NaN  Alabama         1.0
# 1                                                    NaN  Alabama         1.0
# 2                                                    NaN  Alabama         1.0
# 3                                                    NaN  Alabama         1.0
# 4                                                    NaN  Alabama         1.0
# ...                                                  ...      ...         ...
# 17949                                                ---      NaN         NaN
# 17950                                           Caveats:      NaN         NaN
# 17951  1. Please read the Cautions and Limitations se...      NaN         NaN
# 17952  http://wonder.cdc.gov/wonder/help/PM.html#Caut...      NaN         NaN
# 17953  2. Note that values above 65 ug/m3 were set to...      NaN         NaN
#
#       Month Day, Year Month Day, Year Code  \
# 0        Jan 01, 2011           2011/01/01
# 1        Jan 02, 2011           2011/01/02
# 2        Jan 03, 2011           2011/01/03
# 3        Jan 04, 2011           2011/01/04
# 4        Jan 05, 2011           2011/01/05
# ...               ...                  ...
# 17949             NaN                  NaN
# 17950             NaN                  NaN
# 17951             NaN                  NaN
# 17952             NaN                  NaN
# 17953             NaN                  NaN
#
#        Avg Fine Particulate Matter (�g/m�)  \
# 0                                    11.04
# 1                                     4.41
# 2                                     7.94
# 3                                    20.36
# 4                                    20.29
# ...                                    ...
# 17949                                  NaN
# 17950                                  NaN
# 17951                                  NaN
# 17952                                  NaN
# 17953                                  NaN
#
#        # of Observations for Fine Particulate Matter  \
# 0                                             1265.0
# 1                                             1265.0
# 2                                             1265.0
# 3                                             1265.0
# 4                                             1265.0
# ...                                              ...
# 17949                                            NaN
# 17950                                            NaN
# 17951                                            NaN
# 17952                                            NaN
# 17953                                            NaN
#
#        Min Fine Particulate Matter  Max Fine Particulate Matter  \
# 0                              0.0                         31.9
# 1                              2.3                          8.7
# 2                              6.7                          8.4
# 3                             17.2                         22.2
# 4                             17.1                         24.2
# ...                            ...                          ...
# 17949                          NaN                          NaN
# 17950                          NaN                          NaN
# 17951                          NaN                          NaN
# 17952                          NaN                          NaN
# 17953                          NaN                          NaN
#
#        Avg Fine Particulate Matter Standard Deviation
# 0                                                9.78
# 1                                                1.16
# 2                                                0.22
# 3                                                1.20
# 4                                                2.14
# ...                                               ...
# 17949                                             NaN
# 17950                                             NaN
# 17951                                             NaN
# 17952                                             NaN
# 17953                                             NaN
#
# [17954 rows x 10 columns]
